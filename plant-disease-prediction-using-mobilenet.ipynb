# %% [markdown]
# <a href="https://www.kaggle.com/code/shariqaftab333/plant-disease-prediction-using-mobilenet?scriptVersionId=139463309" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import MobileNet
# Out:
# Using TensorFlow backend.

# %%
disease_types = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = '../input/plantdisease/PlantVillage/'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  DiseaseID  \
# 20634  Tomato_healthy/55bcfcce-70f4-4634-8107-0a8207d...         14
# 20635  Tomato_healthy/81024038-40ff-40c4-b8f4-4a48b08...         14
# 20636  Tomato_healthy/058ade43-2361-4039-bbe5-0ac6618...         14
# 20637  Tomato_healthy/2e485f1d-5aa5-4d56-8733-9625ed4...         14
# 20638  Tomato_healthy/d984f436-1fde-4221-9563-82f55a4...         14
#
#          Disease Type
# 20634  Tomato_healthy
# 20635  Tomato_healthy
# 20636  Tomato_healthy
# 20637  Tomato_healthy
# 20638  Tomato_healthy

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/7181181c-b571-4cf0-80c3-c52bd78...         14
# 1  Potato___Early_blight/89d4dba2-3d9c-46fe-bac3-...          2
# 2  Tomato_Septoria_leaf_spot/18f0fcbe-a99c-4d0d-a...          9
# 3  Tomato_healthy/621419a1-09f2-4a22-a569-6d81038...         14
# 4  Tomato_Leaf_Mold/6ffea8bd-57cd-4fcf-b477-decec...          8
#
#                 Disease Type
# 0             Tomato_healthy
# 1      Potato___Early_blight
# 2  Tomato_Septoria_leaf_spot
# 3             Tomato_healthy
# 4           Tomato_Leaf_Mold

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 20639it [02:45, 124.90it/s]
# Train Shape: (20639, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_mobilenet():
    mobilenet = MobileNet(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, N_ch))

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = mobilenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15, activation='softmax', name='root')(x)

    # model
    model = Model(input, output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
import requests

try:
    response = requests.get("https://www.google.com")
    print("Internet is working.")
except requests.ConnectionError:
    print("Internet is not working.")
# Out:
# Internet is working.

# %%
model = build_mobilenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# mobilenet_1.00_224 (Model)   (None, 2, 2, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                3855
# =================================================================
# Total params: 3,500,323
# Trainable params: 3,475,875
# Non-trainable params: 24,448
# _________________________________________________________________
# Epoch 1/50
#  - 41s - loss: 2.9803 - accuracy: 0.2411 - val_loss: 1.5043 - val_accuracy: 0.5635
#
# Epoch 00001: val_loss improved from inf to 1.50425, saving model to model.h5
# Epoch 2/50
#  - 26s - loss: 1.4851 - accuracy: 0.5645 - val_loss: 0.9952 - val_accuracy: 0.7052
#
# Epoch 00002: val_loss improved from 1.50425 to 0.99518, saving model to model.h5
# Epoch 3/50
#  - 27s - loss: 0.9310 - accuracy: 0.7043 - val_loss: 0.7476 - val_accuracy: 0.7624
#
# Epoch 00003: val_loss improved from 0.99518 to 0.74756, saving model to model.h5
# Epoch 4/50
#  - 27s - loss: 0.6962 - accuracy: 0.7739 - val_loss: 0.5987 - val_accuracy: 0.8067
#
# Epoch 00004: val_loss improved from 0.74756 to 0.59872, saving model to model.h5
# Epoch 5/50
#  - 27s - loss: 0.5584 - accuracy: 0.8177 - val_loss: 0.6313 - val_accuracy: 0.8047
#
# Epoch 00005: val_loss did not improve from 0.59872
# Epoch 6/50
#  - 26s - loss: 0.4712 - accuracy: 0.8474 - val_loss: 1.0746 - val_accuracy: 0.6788
#
# Epoch 00006: val_loss did not improve from 0.59872
# Epoch 7/50
#  - 27s - loss: 0.4047 - accuracy: 0.8654 - val_loss: 0.5336 - val_accuracy: 0.8341
#
# Epoch 00007: val_loss improved from 0.59872 to 0.53358, saving model to model.h5
# Epoch 8/50
#  - 26s - loss: 0.3568 - accuracy: 0.8837 - val_loss: 0.4410 - val_accuracy: 0.8614
#
# Epoch 00008: val_loss improved from 0.53358 to 0.44104, saving model to model.h5
# Epoch 9/50
#  - 26s - loss: 0.3240 - accuracy: 0.8913 - val_loss: 0.5312 - val_accuracy: 0.8266
#
# Epoch 00009: val_loss did not improve from 0.44104
# Epoch 10/50
#  - 27s - loss: 0.2999 - accuracy: 0.9024 - val_loss: 0.4451 - val_accuracy: 0.8631
#
# Epoch 00010: val_loss did not improve from 0.44104
# Epoch 11/50
#  - 26s - loss: 0.2652 - accuracy: 0.9148 - val_loss: 0.3611 - val_accuracy: 0.8861
#
# Epoch 00011: val_loss improved from 0.44104 to 0.36111, saving model to model.h5
# Epoch 12/50
#  - 27s - loss: 0.2463 - accuracy: 0.9197 - val_loss: 0.4058 - val_accuracy: 0.8738
#
# Epoch 00012: val_loss did not improve from 0.36111
# Epoch 13/50
#  - 26s - loss: 0.2357 - accuracy: 0.9220 - val_loss: 1.0847 - val_accuracy: 0.7088
#
# Epoch 00013: val_loss did not improve from 0.36111
# Epoch 14/50
#  - 26s - loss: 0.2218 - accuracy: 0.9296 - val_loss: 0.5221 - val_accuracy: 0.8464
#
# Epoch 00014: val_loss did not improve from 0.36111
# Epoch 15/50
#  - 26s - loss: 0.2116 - accuracy: 0.9298 - val_loss: 0.5191 - val_accuracy: 0.8457
#
# Epoch 00015: val_loss did not improve from 0.36111
# Epoch 16/50
#  - 26s - loss: 0.1913 - accuracy: 0.9376 - val_loss: 0.3727 - val_accuracy: 0.8852
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00016: val_loss did not improve from 0.36111
# Epoch 17/50
#  - 26s - loss: 0.1747 - accuracy: 0.9432 - val_loss: 0.2888 - val_accuracy: 0.9077
#
# Epoch 00017: val_loss improved from 0.36111 to 0.28876, saving model to model.h5
# Epoch 18/50
#  - 26s - loss: 0.1665 - accuracy: 0.9443 - val_loss: 0.4971 - val_accuracy: 0.8580
#
# Epoch 00018: val_loss did not improve from 0.28876
# Epoch 19/50
#  - 26s - loss: 0.1658 - accuracy: 0.9471 - val_loss: 0.1446 - val_accuracy: 0.9523
#
# Epoch 00019: val_loss improved from 0.28876 to 0.14458, saving model to model.h5
# Epoch 20/50
#  - 26s - loss: 0.1562 - accuracy: 0.9481 - val_loss: 0.3484 - val_accuracy: 0.8934
#
# Epoch 00020: val_loss did not improve from 0.14458
# Epoch 21/50
#  - 26s - loss: 0.1544 - accuracy: 0.9503 - val_loss: 0.2294 - val_accuracy: 0.9276
#
# Epoch 00021: val_loss did not improve from 0.14458
# Epoch 22/50
#  - 26s - loss: 0.1510 - accuracy: 0.9511 - val_loss: 0.3852 - val_accuracy: 0.8818
#
# Epoch 00022: val_loss did not improve from 0.14458
# Epoch 23/50
#  - 27s - loss: 0.1407 - accuracy: 0.9537 - val_loss: 0.4293 - val_accuracy: 0.8828
#
# Epoch 00023: val_loss did not improve from 0.14458
# Epoch 24/50
#  - 27s - loss: 0.1472 - accuracy: 0.9523 - val_loss: 0.5527 - val_accuracy: 0.8387
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00024: val_loss did not improve from 0.14458
# Epoch 25/50
#  - 27s - loss: 0.1434 - accuracy: 0.9528 - val_loss: 0.6718 - val_accuracy: 0.8081
#
# Epoch 00025: val_loss did not improve from 0.14458
# Epoch 26/50
#  - 26s - loss: 0.1368 - accuracy: 0.9559 - val_loss: 0.2337 - val_accuracy: 0.9261
#
# Epoch 00026: val_loss did not improve from 0.14458
# Epoch 27/50
#  - 26s - loss: 0.1289 - accuracy: 0.9568 - val_loss: 0.1540 - val_accuracy: 0.9489
#
# Epoch 00027: val_loss did not improve from 0.14458
# Epoch 28/50
#  - 26s - loss: 0.1225 - accuracy: 0.9587 - val_loss: 0.3734 - val_accuracy: 0.8893
#
# Epoch 00028: val_loss did not improve from 0.14458
# Epoch 29/50
#  - 26s - loss: 0.1214 - accuracy: 0.9596 - val_loss: 0.3472 - val_accuracy: 0.8968
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00029: val_loss did not improve from 0.14458
# Epoch 30/50
#  - 26s - loss: 0.1188 - accuracy: 0.9619 - val_loss: 0.2698 - val_accuracy: 0.9184
#
# Epoch 00030: val_loss did not improve from 0.14458
# Epoch 31/50
#  - 26s - loss: 0.1176 - accuracy: 0.9622 - val_loss: 0.3868 - val_accuracy: 0.8907
#
# Epoch 00031: val_loss did not improve from 0.14458
# Epoch 32/50
#  - 26s - loss: 0.1199 - accuracy: 0.9610 - val_loss: 0.4994 - val_accuracy: 0.8578
#
# Epoch 00032: val_loss did not improve from 0.14458
# Epoch 33/50
#  - 27s - loss: 0.1186 - accuracy: 0.9615 - val_loss: 0.6049 - val_accuracy: 0.8304
#
# Epoch 00033: val_loss did not improve from 0.14458
# Epoch 34/50
#  - 26s - loss: 0.1108 - accuracy: 0.9650 - val_loss: 0.1805 - val_accuracy: 0.9431
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00034: val_loss did not improve from 0.14458
# Epoch 35/50
#  - 26s - loss: 0.1105 - accuracy: 0.9639 - val_loss: 0.7341 - val_accuracy: 0.8239
#
# Epoch 00035: val_loss did not improve from 0.14458
# Epoch 36/50
#  - 26s - loss: 0.1081 - accuracy: 0.9657 - val_loss: 0.2608 - val_accuracy: 0.9181
#
# Epoch 00036: val_loss did not improve from 0.14458
# Epoch 37/50
#  - 26s - loss: 0.1072 - accuracy: 0.9664 - val_loss: 0.2314 - val_accuracy: 0.9276
#
# Epoch 00037: val_loss did not improve from 0.14458
# Epoch 38/50
#  - 26s - loss: 0.1013 - accuracy: 0.9673 - val_loss: 0.2946 - val_accuracy: 0.9164
#
# Epoch 00038: val_loss did not improve from 0.14458
# Epoch 39/50
#  - 26s - loss: 0.1018 - accuracy: 0.9653 - val_loss: 0.1607 - val_accuracy: 0.9494
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00039: val_loss did not improve from 0.14458
# Epoch 40/50
#  - 26s - loss: 0.1037 - accuracy: 0.9646 - val_loss: 0.2142 - val_accuracy: 0.9302
#
# Epoch 00040: val_loss did not improve from 0.14458
# Epoch 41/50
#  - 26s - loss: 0.0948 - accuracy: 0.9698 - val_loss: 0.1645 - val_accuracy: 0.9499
#
# Epoch 00041: val_loss did not improve from 0.14458
# Epoch 42/50
#  - 26s - loss: 0.0899 - accuracy: 0.9703 - val_loss: 0.2664 - val_accuracy: 0.9230
#
# Epoch 00042: val_loss did not improve from 0.14458
# Epoch 43/50
#  - 26s - loss: 0.0903 - accuracy: 0.9704 - val_loss: 0.2389 - val_accuracy: 0.9295
#
# Epoch 00043: val_loss did not improve from 0.14458
# Epoch 44/50
#  - 26s - loss: 0.0924 - accuracy: 0.9698 - val_loss: 0.1667 - val_accuracy: 0.9438
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00044: val_loss did not improve from 0.14458
# Epoch 45/50
#  - 26s - loss: 0.0950 - accuracy: 0.9692 - val_loss: 0.1691 - val_accuracy: 0.9462
#
# Epoch 00045: val_loss did not improve from 0.14458
# Epoch 46/50
#  - 26s - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.3979 - val_accuracy: 0.8939
#
# Epoch 00046: val_loss did not improve from 0.14458
# Epoch 47/50
#  - 26s - loss: 0.0887 - accuracy: 0.9703 - val_loss: 0.3348 - val_accuracy: 0.9079
#
# Epoch 00047: val_loss did not improve from 0.14458
# Epoch 48/50
#  - 25s - loss: 0.0859 - accuracy: 0.9728 - val_loss: 0.6697 - val_accuracy: 0.8433
#
# Epoch 00048: val_loss did not improve from 0.14458
# Epoch 49/50
#  - 26s - loss: 0.0890 - accuracy: 0.9718 - val_loss: 0.7561 - val_accuracy: 0.8207
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00049: val_loss did not improve from 0.14458
# Epoch 50/50
#  - 26s - loss: 0.0842 - accuracy: 0.9723 - val_loss: 0.1987 - val_accuracy: 0.9387
#
# Epoch 00050: val_loss did not improve from 0.14458

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 4128/4128 [==============================] - 1s 305us/step
# Final Loss: 0.19870217635419019, Final Accuracy: 0.9387112259864807

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 144.41374999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [6.51929807e-03 8.80740024e-03 1.13445438e-01 9.12866928e-03
#  2.45060064e-02 1.59964882e-04 3.51429568e-03 1.04994997e-01
#  1.24222055e-01 5.07445395e-01 1.14733943e-04 1.34391617e-03
#  5.11803883e-05 2.93937325e-03 9.28072557e-02]
# Prediction: Tomato_Septoria_leaf_spot
